# %% [markdown]
# # Redrob Intelligent Candidate Ranker - Sandbox Demo
# This notebook demonstrates the end-to-end candidate ranking pipeline on a small sample of 100 candidates.

# %%
# 1. Clone the repository
# TODO: Replace with your actual GitHub repository URL before sharing
# !git clone https://github.com/YOUR_USERNAME/redrob-candidate-ranker.git
# %cd redrob-candidate-ranker

# %%
# 2. Install dependencies
# !pip install -r requirements.txt

# %%
# 3. Run Precomputation (Offline step)
# We run this on a provided 100-candidate sample JSONL
# !python precompute.py --candidates sample_100.jsonl

# %%
# 4. Run Ranking (Online step)
# !python rank.py --candidates sample_100.jsonl --out sandbox_submission.csv

# %%
# 5. View Top Results
import pandas as pd
df = pd.read_csv('sandbox_submission.csv')
display(df.head())
